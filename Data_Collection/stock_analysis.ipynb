# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from symbol_fetcher import SymbolFetcher
from yahoo_helper import Yahoohelper

yhelper = Yahoohelper()
shelper = SymbolFetcher()

# %% [markdown]
# ## Nasdaq 100

# %%
# Get nasdaq-100 symbols
nasdaq_symbols = shelper.get_nasdaq_symbols()

print("Number of Active Stock Symbols:", len(nasdaq_symbols))
print("Example Active Stock Symbols:", nasdaq_symbols)
# Out:
# Number of Active Stock Symbols: 92
# Example Active Stock Symbols: ['CPRT', 'AMGN', 'CMCSA', 'INTC', 'KLAC', 'PCAR', 'CTAS', 'PAYX', 'LRCX', 'ADSK', 'ROST', 'MNST', 'ADBE', 'FAST', 'EA', 'CSCO', 'REGN', 'IDXX', 'VRTX', 'BIIB', 'ODFL', 'QCOM', 'GILD', 'SNPS', 'SBUX', 'SIRI', 'INTU', 'MCHP', 'ORLY', 'DLTR', 'ASML', 'ANSS', 'CTSH', 'CSGP', 'EBAY', 'BKNG', 'ON', 'ISRG', 'MRVL', 'ILMN', 'ADI', 'AEP', 'CDNS', 'CSX', 'HON', 'MU', 'XEL', 'EXC', 'PEP', 'TXN', 'WBA', 'ALGN', 'SGEN', 'MDLZ', 'DXCM', 'TMUS', 'MELI', 'AVGO', 'VRSK', 'FTNT', 'CHTR', 'NXPI', 'ENPH', 'FANG', 'PANW', 'WDAY', 'GOOG', 'JD', 'PYPL', 'KHC', 'TEAM', 'BKR', 'ZS', 'PDD', 'MRNA', 'CRWD', 'ZM', 'DDOG', 'ABNB', 'CEG', 'GFS', 'AZN', 'TTD', 'LULU', 'AMAT', 'GEHC', 'KDP', 'WBD', 'COST', 'LCID', 'MAR', 'ADP']

# %% [markdown]
# Create a csv file based on the nasdaq symols

# %%
# Define the data folder and CSV file path
data_folder = 'data'
filename = "nasdaq_monthly_adjusted.csv"
end_date = "2023-09-05"
start_date = "2000-01-01"
# Store nasdaq data in csv file
yhelper.extend_stock_data_csv(symbols=nasdaq_symbols, folder=data_folder, filename=filename,
                              start_date=start_date, end_date=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CPRT saved to: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for AMGN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CMCSA extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for INTC extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for KLAC extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for PCAR extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CTAS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for PAYX extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for LRCX extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ADSK extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ROST extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MNST extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ADBE extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for FAST extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for EA extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CSCO extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for REGN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for IDXX extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for VRTX extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for BIIB extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ODFL extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for QCOM extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for GILD extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for SNPS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for SBUX extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for SIRI extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for INTU extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MCHP extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ORLY extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for DLTR extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ASML extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ANSS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CTSH extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CSGP extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for EBAY extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for BKNG extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ON extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ISRG extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MRVL extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ILMN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ADI extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for AEP extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CDNS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CSX extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for HON extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MU extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for XEL extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for EXC extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for PEP extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for TXN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for WBA extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ALGN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for SGEN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MDLZ extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for DXCM extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for TMUS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MELI extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for AVGO extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for VRSK extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for FTNT extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CHTR extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for NXPI extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ENPH extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for FANG extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for PANW extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for WDAY extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for GOOG extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for JD extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for PYPL extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for KHC extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for TEAM extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for BKR extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ZS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for PDD extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MRNA extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CRWD extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ZM extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for DDOG extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ABNB extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for CEG extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for GFS extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for AZN extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for TTD extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for LULU extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for AMAT extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for GEHC extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for KDP extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for WBD extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for COST extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for LCID extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for MAR extended in: data/nasdaq_monthly_adjusted.csv
# [*********************100%%**********************]  1 of 1 completed
# CSV data for ADP extended in: data/nasdaq_monthly_adjusted.csv

# %% [markdown]
# Plot the nasdaq data

# %%
# Load the CSV data into a DataFrame
csv_file_path = 'data/nasdaq_monthly_adjusted.csv'  # Replace with the actual path
df = pd.read_csv(csv_file_path)

# Convert the 'Date' column to a datetime object
df['date'] = pd.to_datetime(df['Date'])

sns.lineplot(data=df, x="date", y="Adj Close")
# Out:
# <Axes: xlabel='date', ylabel='Adj Close'>
